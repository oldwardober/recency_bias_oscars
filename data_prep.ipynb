# %%
import pandas as pd
import numpy as np
import ydata_profiling

# %% [markdown]
# Data from 3 different sources

# %%
nominations = pd.read_csv('the_oscar_award.csv')
oscars_dates = pd.read_csv('oscars_dates.csv')
ratings = pd.read_csv('rotten_tomatoes_movies.csv')

# %%
display(nominations.head())
display(oscars_dates.head())
display(ratings.head())
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False
#    Oscars  Year        Date                    Best Picture
# 0       1  1929  16.05.1929                           Wings
# 1       2  1930  03.04.1930             The Broadway Melody
# 2       3  1930  05.11.1930  All Quiet on the Western Front
# 3       4  1931  10.11.1931                        Cimarron
# 4       5  1932  18.11.1932                     Grand Hotel
#                      id                title  audienceScore  tomatoMeter  \
# 0    space-zombie-bingo  Space Zombie Bingo!           50.0          NaN
# 1       the_green_grass      The Green Grass            NaN          NaN
# 2             love_lies           Love, Lies           43.0          NaN
# 3  the_sore_losers_1997          Sore Losers           60.0          NaN
# 4  dinosaur_island_2002      Dinosaur Island           70.0          NaN
#
#   rating ratingContents releaseDateTheaters releaseDateStreaming  \
# 0    NaN            NaN                 NaN           2018-08-25
# 1    NaN            NaN                 NaN           2020-02-11
# 2    NaN            NaN                 NaN                  NaN
# 3    NaN            NaN                 NaN           2020-10-23
# 4    NaN            NaN                 NaN           2017-03-27
#
#    runtimeMinutes                          genre originalLanguage  \
# 0            75.0         Comedy, Horror, Sci-fi          English
# 1           114.0                          Drama          English
# 2           120.0                          Drama           Korean
# 3            90.0     Action, Mystery & thriller          English
# 4            80.0  Fantasy, Adventure, Animation          English
#
#                         director                                  writer  \
# 0                  George Ormrod              George Ormrod,John Sabotta
# 1                Tiffany Edwards                         Tiffany Edwards
# 2  Park Heung-Sik,Heung-Sik Park  Ha Young-Joon,Jeon Yun-su,Song Hye-jin
# 3          John Michael McCarthy                   John Michael McCarthy
# 4                  Will Meugniot                                John Loy
#
#   boxOffice distributor soundMix
# 0       NaN         NaN      NaN
# 1       NaN         NaN      NaN
# 2       NaN         NaN      NaN
# 3       NaN         NaN      NaN
# 4       NaN         NaN      NaN

# %% [markdown]
# Joining data

# %%
#I want to have exact date of oscar ceremony in order to calculate difference between this date and the release date of each movie
oscars = pd.merge(nominations, oscars_dates, left_on= "year_ceremony", right_on = "Year")

#I don't need some of the columns
oscars = oscars.drop(['Oscars', 'Year', 'Best Picture'], axis = 1)

# %%
#changing false/true in a 'winner' column to 0/1
oscars["winner"] = oscars["winner"].astype(int)

# %%
#let's create movie ID so the get rid of the potentail duplicates (title + year)
oscars['film'] = oscars['film'].replace(';', '', regex = True) #I found ";" character in some film titles

oscars['film_id'] = oscars['film'].astype(str).str.lower()
oscars['film_id'] = oscars['film_id'].str.replace(' ', '_')
oscars['film_id'] = oscars['film_id'] + '_' + oscars['year_film'].astype(str)

# %%
#pandas profiling

#report = oscars.profile_report()
#report.to_file(output_file = "oscars_report.html")

# %%
oscars = oscars.dropna()
print(oscars.isnull().sum())
# Out:
# year_film        0
# year_ceremony    0
# ceremony         0
# category         0
# name             0
# film             0
# winner           0
# Date             0
# film_id          0
# dtype: int64

# %%
oscars_count = oscars.groupby(['film_id','film','year_film', 'year_ceremony', 'Date'])['winner'].agg(['sum', 'count']).sort_values('sum', ascending = False).reset_index()
oscars_count.head(5)
# Out:
#                                              film_id  \
# 0                                       ben-hur_1959
# 1                                       titanic_1997
# 2  the_lord_of_the_rings:_the_return_of_the_king_...
# 3                               west_side_story_1961
# 4                              the_last_emperor_1987
#
#                                             film  year_film  year_ceremony  \
# 0                                        Ben-Hur       1959           1960
# 1                                        Titanic       1997           1998
# 2  The Lord of the Rings: The Return of the King       2003           2004
# 3                                West Side Story       1961           1962
# 4                               The Last Emperor       1987           1988
#
#          Date  sum  count
# 0  04.04.1960   11     12
# 1  23.03.1998   11     14
# 2  29.02.2004   11     11
# 3  09.04.1962   10     11
# 4  11.04.1988    9      9

# %%
#changing column names
oscars_count.columns = ['film_id', 'film', 'year_film', 'year_ceremony', 'date_ceremony', 'oscars', 'nominations']
oscars_count['date_ceremony'] = pd.to_datetime(oscars_count['date_ceremony'])
oscars_count.head()
# Out:
#                                              film_id  \
# 0                                       ben-hur_1959
# 1                                       titanic_1997
# 2  the_lord_of_the_rings:_the_return_of_the_king_...
# 3                               west_side_story_1961
# 4                              the_last_emperor_1987
#
#                                             film  year_film  year_ceremony  \
# 0                                        Ben-Hur       1959           1960
# 1                                        Titanic       1997           1998
# 2  The Lord of the Rings: The Return of the King       2003           2004
# 3                                West Side Story       1961           1962
# 4                               The Last Emperor       1987           1988
#
#   date_ceremony  oscars  nominations
# 0    1960-04-04      11           12
# 1    1998-03-23      11           14
# 2    2004-02-29      11           11
# 3    1962-09-04      10           11
# 4    1988-11-04       9            9

# %%
#now time to merge with the ratings datasets, again I don't need all the columns
ratings = ratings.drop(['ratingContents', 'releaseDateStreaming', 'director', 'writer', 'distributor', 'soundMix'], axis = 1)

# %%
#I don't like this id column so I will create new one (again title + year)

#release date is the most important column so I drop rows with NA's in that column
ratings = ratings[ratings['releaseDateTheaters'].notna()] 

ratings['releaseDateTheaters'] = pd.to_datetime(ratings['releaseDateTheaters'])
ratings['film_id'] = ratings['title'].astype(str).str.lower()
ratings['film_id'] = ratings['film_id'].str.replace(' ', '_')
ratings['film_id'] = ratings['film_id'] + '_' + ratings['releaseDateTheaters'].dt.year.astype(str)

# %%
#merging

oscars_merged = pd.merge(oscars_count, ratings, how = 'left', left_on = 'film_id', right_on = 'film_id')

# %%
oscars_merged.tail(20)
# Out:
#                                film_id                         film  \
# 5130                       kismet_1944                       Kismet
# 5131                 kiss_me_kate_1953                 Kiss Me Kate
# 5132                kiss_of_death_1947                Kiss of Death
# 5133                      kitbull_2019                      Kitbull
# 5134                        kotch_1971                        Kotch
# 5135                        kitty_1946                        Kitty
# 5136                        klaus_2019                        Klaus
# 5137     kleingeld_(small_change)_1999     Kleingeld (Small Change)
# 5138                klondike_fury_1942                Klondike Fury
# 5139        knickerbocker_holiday_1944        Knickerbocker Holiday
# 5140           knife_in_the_water_1963           Knife in the Water
# 5141                 knife_skills_2017                 Knife Skills
# 5142            knight_of_fortune_2023            Knight of Fortune
# 5143   knights_of_the_round_table_1953   Knights of the Round Table
# 5144                   knives_out_2019                   Knives Out
# 5145                knock_on_wood_1954                Knock on Wood
# 5146                     kon-tiki_2012                     Kon-Tiki
# 5147           kong:_skull_island_2017           Kong: Skull Island
# 5148                koryo_celadon_1979                Koryo Celadon
# 5149  éramos_pocos_(one_too_many)_2006  Éramos Pocos (One Too Many)
#
#       year_film  year_ceremony date_ceremony  oscars  nominations  \
# 5130       1944           1945    1945-03-15       0            4
# 5131       1953           1954    1954-03-25       0            1
# 5132       1947           1948    1948-03-20       0            2
# 5133       2019           2020    2020-09-02       0            1
# 5134       1971           1972    1972-10-04       0            4
# 5135       1946           1947    1947-03-13       0            1
# 5136       2019           2020    2020-09-02       0            1
# 5137       1999           2000    2000-03-26       0            1
# 5138       1942           1943    1943-04-03       0            1
# 5139       1944           1945    1945-03-15       0            1
# 5140       1963           1964    1964-04-13       0            1
# 5141       2017           2018    2018-04-03       0            1
# 5142       2023           2024    2024-10-03       0            1
# 5143       1953           1954    1954-03-25       0            2
# 5144       2019           2020    2020-09-02       0            1
# 5145       1954           1955    1955-03-30       0            1
# 5146       2012           2013    2013-02-24       0            1
# 5147       2017           2018    2018-04-03       0            1
# 5148       1979           1980    1980-04-14       0            1
# 5149       2006           2007    2007-02-25       0            1
#
#                               id                       title  audienceScore  \
# 5130                 kismet_1944                      Kismet           38.0
# 5131            kiss-me-kate1953                Kiss Me Kate           67.0
# 5132       1029072-kiss_of_death               Kiss of Death           76.0
# 5133                         NaN                         NaN            NaN
# 5134                       kotch                       Kotch           67.0
# 5135                         NaN                         NaN            NaN
# 5136                       klaus                       Klaus           96.0
# 5137                         NaN                         NaN            NaN
# 5138                         NaN                         NaN            NaN
# 5139       knickerbocker_holiday       Knickerbocker Holiday            NaN
# 5140                         NaN                         NaN            NaN
# 5141                         NaN                         NaN            NaN
# 5142                         NaN                         NaN            NaN
# 5143  knights_of_the_round_table  Knights of the Round Table           42.0
# 5144                  knives_out                  Knives Out           92.0
# 5145               knock-on-wood               Knock on Wood           62.0
# 5146                         NaN                         NaN            NaN
# 5147           kong_skull_island          Kong: Skull Island           69.0
# 5148                         NaN                         NaN            NaN
# 5149                         NaN                         NaN            NaN
#
#       tomatoMeter rating releaseDateTheaters  runtimeMinutes  \
# 5130          NaN    NaN          1944-08-22           100.0
# 5131         93.0    NaN          1953-11-26           109.0
# 5132         88.0    NaN          1947-08-27            98.0
# 5133          NaN    NaN                 NaT             NaN
# 5134         75.0    NaN          1971-09-17           118.0
# 5135          NaN    NaN                 NaT             NaN
# 5136         95.0     PG          2019-11-08            98.0
# 5137          NaN    NaN                 NaT             NaN
# 5138          NaN    NaN                 NaT             NaN
# 5139          NaN    NaN          1944-03-17            85.0
# 5140          NaN    NaN                 NaT             NaN
# 5141          NaN    NaN                 NaT             NaN
# 5142          NaN    NaN                 NaT             NaN
# 5143         67.0    NaN          1953-12-22           115.0
# 5144         97.0  PG-13          2019-11-27           130.0
# 5145          NaN    NaN          1954-04-14           103.0
# 5146          NaN    NaN                 NaT             NaN
# 5147         75.0  PG-13          2017-03-10           118.0
# 5148          NaN    NaN                 NaT             NaN
# 5149          NaN    NaN                 NaT             NaN
#
#                                                   genre originalLanguage  \
# 5130                                            Fantasy          English
# 5131                                    Musical, Comedy          English
# 5132                                       Crime, Drama          English
# 5133                                                NaN              NaN
# 5134                                      Comedy, Drama          English
# 5135                                                NaN              NaN
# 5136  Kids & family, Holiday, Comedy, Adventure, Ani...          English
# 5137                                                NaN              NaN
# 5138                                                NaN              NaN
# 5139                                    Musical, Comedy          English
# 5140                                                NaN              NaN
# 5141                                                NaN              NaN
# 5142                                                NaN              NaN
# 5143                                          Adventure          English
# 5144                  Mystery & thriller, Comedy, Drama          English
# 5145                                             Comedy          English
# 5146                                                NaN              NaN
# 5147                 Adventure, Action, Sci-fi, Fantasy          English
# 5148                                                NaN              NaN
# 5149                                                NaN              NaN
#
#      boxOffice
# 5130       NaN
# 5131       NaN
# 5132       NaN
# 5133       NaN
# 5134       NaN
# 5135       NaN
# 5136       NaN
# 5137       NaN
# 5138       NaN
# 5139       NaN
# 5140       NaN
# 5141       NaN
# 5142       NaN
# 5143       NaN
# 5144   $165.4M
# 5145       NaN
# 5146       NaN
# 5147   $168.0M
# 5148       NaN
# 5149       NaN

# %%
print(oscars_merged.isnull().sum()) #sporo NA's...
# Out:
# film_id                   0
# film                      0
# year_film                 0
# year_ceremony             0
# date_ceremony             0
# oscars                    0
# nominations               0
# id                     2367
# title                  2367
# audienceScore          2461
# tomatoMeter            2829
# rating                 4440
# releaseDateTheaters    2367
# runtimeMinutes         2374
# genre                  2367
# originalLanguage       2375
# boxOffice              4006
# dtype: int64

# %%
#pandas profiling

#report = oscars_merged.profile_report()
#report.to_file(output_file = "oscars_report.html")

# %%
oscars_merged = oscars_merged.drop_duplicates()
oscars_merged = oscars_merged[oscars_merged['title'].notna()] #I'm dropping a lot of observations but well...

# %%
#Adding difference between release date and the oscar ceremony date (in days)

oscars_merged['days_to_ceremony'] = (oscars_merged['date_ceremony'] - oscars_merged['releaseDateTheaters']).dt.days

# %%
oscars_merged = oscars_merged.drop(['id', 'title'], axis=1)

# %%
#we should probably group the "genre" column (there are to many distinct values)
print(oscars_merged['genre'].nunique())
oscars_merged['genre'] = oscars_merged['genre'].str.split(',', 1).str[0].str.strip()
print(oscars_merged['genre'].nunique())
# Out:
# 357
# 18

# %%
oscars_merged['originalLanguage'].unique()
# Out:
# array(['English', nan, 'English (United Kingdom)', 'Chinese', 'German',
#        'Korean', 'Italian', 'Spanish (Spain)', 'Spanish',
#        'French (France)', 'French (Canada)', 'Russian', 'Japanese',
#        'Czech', 'Polish', 'Turkish', 'Portuguese (Brazil)', 'Swedish',
#        'Persian', 'Danish', 'Dutch', 'English (Australia)', 'Arabic',
#        'Telugu', 'Hindi', 'Indonesian', 'Hungarian', 'Hebrew', 'Aramaic',
#        'Romanian', 'Greek', 'Unknown language', 'Afrikaans'], dtype=object)

# %%
#column yes/no based on whether the language is english or not
oscars_merged['English'] = ['Yes' if x in ['English', 'English (United Kingdom)', 'English (Australia)'] else 'No' for x in oscars_merged['originalLanguage']]

# %%
oscars_merged['English'].value_counts()
# Out:
# Yes    2568
# No      195
# Name: English, dtype: int64

# %%
#oscars_merged.to_csv('oscars_merged.csv', index = False)

# %% [markdown]
# # Data prep for movies from the best picture category

# %%
nom_bestpicture = nominations.loc[nominations['category'].isin(['BEST PICTURE', 'OUTSTANDING PRODUCTION', 'OUTSTANDING PICTURE', 'OUTSTANDING MOTION PICTURE', 'BEST MOTION PICTURE'])].reset_index(drop=True)
nom_bestpicture.head()
# Out:
#    year_film  year_ceremony  ceremony             category  \
# 0       1927           1928         1  OUTSTANDING PICTURE
# 1       1927           1928         1  OUTSTANDING PICTURE
# 2       1927           1928         1  OUTSTANDING PICTURE
# 3       1928           1929         2  OUTSTANDING PICTURE
# 4       1928           1929         2  OUTSTANDING PICTURE
#
#                      name            film  winner
# 0       The Caddo Company      The Racket   False
# 1                     Fox      7th Heaven   False
# 2  Paramount Famous Lasky           Wings    True
# 3     Feature Productions           Alibi   False
# 4                     Fox  In Old Arizona   False

# %%
best_picture = pd.merge(nom_bestpicture, oscars_dates, left_on= "year_ceremony", right_on = "Year")
best_picture = best_picture.drop(['Oscars', 'Year', 'Best Picture'], axis = 1)

# %%
best_picture["winner"] = best_picture["winner"].astype(int)

# %%
best_picture['film'] = best_picture['film'].replace(';', '', regex = True) #I found ";" character in some film titles

best_picture['film_id'] = best_picture['film'].astype(str).str.lower()
best_picture['film_id'] = best_picture['film_id'].str.replace(' ', '_')
best_picture['film_id'] = best_picture['film_id'] + '_' + best_picture['year_film'].astype(str)

# %%
print(oscars.isnull().sum())
# Out:
# year_film        0
# year_ceremony    0
# ceremony         0
# category         0
# name             0
# film             0
# winner           0
# Date             0
# film_id          0
# dtype: int64

# %%
print(best_picture['film_id'].duplicated())
best_picture['film_id'].drop_duplicates()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# Name: film_id, Length: 593, dtype: bool
# 0                     alibi_1928
# 1            in_old_arizona_1928
# 2       the_broadway_melody_1928
# 3           hollywood_revue_1928
# 4               the_patriot_1928
#                  ...
# 588                 maestro_2023
# 589             oppenheimer_2023
# 590              past_lives_2023
# 591             poor_things_2023
# 592    the_zone_of_interest_2023
# Name: film_id, Length: 588, dtype: object

# %%
display(ratings.head(3))
display(best_picture.head(3))
# Out:
#                       id                 title  audienceScore  tomatoMeter  \
# 5            adrift_2018                Adrift           65.0         69.0
# 9   1035316-born_to_kill          Born to Kill           74.0         83.0
# 12  margarita_happy_hour  Margarita Happy Hour            NaN         76.0
#
#    rating releaseDateTheaters  runtimeMinutes                      genre  \
# 5   PG-13          2018-06-01           120.0  Adventure, Drama, Romance
# 9     NaN          1947-04-30            92.0               Crime, Drama
# 12    NaN          2002-03-22            98.0                      Drama
#
#    originalLanguage boxOffice                    film_id
# 5           English    $31.4M                adrift_2018
# 9           English       NaN          born_to_kill_1947
# 12          English    $11.5K  margarita_happy_hour_2002
#    year_film  year_ceremony  ceremony             category  \
# 0       1928           1929         2  OUTSTANDING PICTURE
# 1       1928           1929         2  OUTSTANDING PICTURE
# 2       1928           1929         2  OUTSTANDING PICTURE
#
#                   name                 film  winner        Date  \
# 0  Feature Productions                Alibi       0  16.05.1929
# 1                  Fox       In Old Arizona       0  16.05.1929
# 2  Metro-Goldwyn-Mayer  The Broadway Melody       1  16.05.1929
#
#                     film_id
# 0                alibi_1928
# 1       in_old_arizona_1928
# 2  the_broadway_melody_1928

# %%
best_picture_merged = pd.merge(best_picture, ratings, how = 'left', left_on = 'film_id', right_on = 'film_id')

# %%
best_picture_merged.isnull().sum()
# Out:
# year_film                0
# year_ceremony            0
# ceremony                 0
# category                 0
# name                     0
# film                     0
# winner                   0
# Date                     0
# film_id                  0
# id                      96
# title                   96
# audienceScore          101
# tomatoMeter             99
# rating                 441
# releaseDateTheaters     96
# runtimeMinutes          98
# genre                   96
# originalLanguage        98
# boxOffice              374
# dtype: int64

# %%
best_picture_merged = best_picture_merged.drop_duplicates()

# %%
best_picture_merged = best_picture_merged[best_picture_merged['title'].notna()]

# %%
best_picture_merged['date_ceremony'] = pd.to_datetime(best_picture_merged['Date'])
best_picture_merged['releaseDateTheaters'] = pd.to_datetime(best_picture_merged['releaseDateTheaters'])


best_picture_merged['days_to_ceremony'] = (best_picture_merged['date_ceremony'] - best_picture_merged['releaseDateTheaters']).dt.days

# %%
best_picture_merged.head()
# Out:
#     year_film  year_ceremony  ceremony                category  \
# 4        1928           1929         2     OUTSTANDING PICTURE
# 9        1929           1930         3  OUTSTANDING PRODUCTION
# 10       1929           1930         3  OUTSTANDING PRODUCTION
# 13       1929           1930         3  OUTSTANDING PRODUCTION
# 14       1929           1930         3  OUTSTANDING PRODUCTION
#
#                       name             film  winner        Date  \
# 4   Paramount Famous Lasky      The Patriot       0  16.05.1929
# 9             Warner Bros.         Disraeli       0  03.04.1930
# 10            Warner Bros.         Disraeli       0  05.11.1930
# 13  Paramount Famous Lasky  The Love Parade       0  03.04.1930
# 14  Paramount Famous Lasky  The Love Parade       0  05.11.1930
#
#                  film_id                id  ... audienceScore  tomatoMeter  \
# 4       the_patriot_1928       the_patriot  ...          55.0        100.0
# 9          disraeli_1929  1005964-disraeli  ...          42.0         83.0
# 10         disraeli_1929  1005964-disraeli  ...          42.0         83.0
# 13  the_love_parade_1929   the-love-parade  ...          77.0        100.0
# 14  the_love_parade_1929   the-love-parade  ...          77.0        100.0
#
#     rating releaseDateTheaters runtimeMinutes            genre  \
# 4      NaN          1928-08-17          108.0   History, Drama
# 9      NaN          1929-11-01           89.0        Biography
# 10     NaN          1929-11-01           89.0        Biography
# 13     NaN          1929-11-19          107.0  Musical, Comedy
# 14     NaN          1929-11-19          107.0  Musical, Comedy
#
#    originalLanguage boxOffice date_ceremony days_to_ceremony
# 4           English       NaN    1929-05-16              272
# 9           English       NaN    1930-03-04              123
# 10          English       NaN    1930-05-11              191
# 13          English       NaN    1930-03-04              105
# 14          English       NaN    1930-05-11              173
#
# [5 rows x 21 columns]

# %%
best_picture_merged = best_picture_merged.drop(['id', 'title', 'Date', 'category', 'name', 'rating', 'date_ceremony'], axis=1)

# %%
print(best_picture_merged['genre'].nunique())
best_picture_merged['genre'] = best_picture_merged['genre'].str.split(',', 1).str[0].str.strip()
print(best_picture_merged['genre'].nunique())
# Out:
# 126
# 17

# %%
best_picture_merged['English'] = ['Yes' if x in ['English', 'English (United Kingdom)', 'English (Australia)'] else 'No' for x in best_picture_merged['originalLanguage']]

# %%
best_picture_merged.head()
# Out:
#     year_film  year_ceremony  ceremony             film  winner  \
# 4        1928           1929         2      The Patriot       0
# 9        1929           1930         3         Disraeli       0
# 10       1929           1930         3         Disraeli       0
# 13       1929           1930         3  The Love Parade       0
# 14       1929           1930         3  The Love Parade       0
#
#                  film_id  audienceScore  tomatoMeter releaseDateTheaters  \
# 4       the_patriot_1928           55.0        100.0          1928-08-17
# 9          disraeli_1929           42.0         83.0          1929-11-01
# 10         disraeli_1929           42.0         83.0          1929-11-01
# 13  the_love_parade_1929           77.0        100.0          1929-11-19
# 14  the_love_parade_1929           77.0        100.0          1929-11-19
#
#     runtimeMinutes      genre originalLanguage boxOffice  days_to_ceremony  \
# 4            108.0    History          English       NaN               272
# 9             89.0  Biography          English       NaN               123
# 10            89.0  Biography          English       NaN               191
# 13           107.0    Musical          English       NaN               105
# 14           107.0    Musical          English       NaN               173
#
#    English
# 4      Yes
# 9      Yes
# 10     Yes
# 13     Yes
# 14     Yes

# %%
best_picture_merged = best_picture_merged.drop(['ceremony', 'originalLanguage'], axis=1)

# %%
best_picture_merged['releaseMonth'] = pd.to_datetime(best_picture_merged['releaseDateTheaters']).dt.month
best_picture_merged = best_picture_merged.drop('releaseDateTheaters', axis=1)

# %%
best_picture_merged = best_picture_merged.drop_duplicates(subset = 'film_id')

# %%
#best_picture_merged.to_csv('best_picture.csv', index = False)
